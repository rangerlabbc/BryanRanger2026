# %%
# !python --version
# Out:
# Python 3.12.13

# %%
# !pip install git+https://github.com/AIM-Harvard/pyradiomics.git
# Out:
# Collecting git+https://github.com/AIM-Harvard/pyradiomics.git
#   Cloning https://github.com/AIM-Harvard/pyradiomics.git to /tmp/pip-req-build-oj_29rym
#   Running command git clone --filter=blob:none --quiet https://github.com/AIM-Harvard/pyradiomics.git /tmp/pip-req-build-oj_29rym
#   Resolved https://github.com/AIM-Harvard/pyradiomics.git to commit 8ed579383b44806651c463d5e691f3b2b57522ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from pyradiomics==3.1.1.dev111+g8ed579383) (2.0.2)
# Requirement already satisfied: SimpleITK>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from pyradiomics==3.1.1.dev111+g8ed579383) (2.5.5)
# Requirement already satisfied: PyWavelets>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pyradiomics==3.1.1.dev111+g8ed579383) (1.9.0)
# Requirement already satisfied: pykwalify>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pyradiomics==3.1.1.dev111+g8ed579383) (1.8.0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from pykwalify>=1.6.0->pyradiomics==3.1.1.dev111+g8ed579383) (0.6.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from pykwalify>=1.6.0->pyradiomics==3.1.1.dev111+g8ed579383) (2.9.0.post0)
# Requirement already satisfied: ruamel.yaml>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from pykwalify>=1.6.0->pyradiomics==3.1.1.dev111+g8ed579383) (0.19.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->pykwalify>=1.6.0->pyradiomics==3.1.1.dev111+g8ed579383) (1.17.0)

# %%
import radiomics
from radiomics import featureextractor

# %%
imagePath, maskPath = radiomics.getTestCase('brain1')
# Out:
# INFO:radiomics:Test case file brain1_image.nrrd not available locally, downloading from github...
# INFO:radiomics:File brain1_image.nrrd downloaded
# INFO:radiomics:Test case file brain1_label.nrrd not available locally, downloading from github...
# INFO:radiomics:File brain1_label.nrrd downloaded
